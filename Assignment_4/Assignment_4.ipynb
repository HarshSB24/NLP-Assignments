# %% [markdown]
# **Assignment 4**

# %% [markdown]
# Build a Named Entity Recognition (NER) system for extracting entities from real-world text
# such as news articles or social media data. And measure its accuracy, precision, recall, and F1-
# score

# %% [markdown]
# **Installing Library**

# %%
# %pip install spacy
print("spaCy library installed.")
# Out:
# Requirement already satisfied: spacy in e:\python\lib\site-packages (3.8.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in e:\python\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in e:\python\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in e:\python\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in e:\python\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in e:\python\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in e:\python\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in e:\python\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in e:\python\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in e:\python\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in e:\python\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in e:\python\lib\site-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in e:\python\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in e:\python\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in e:\python\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in e:\python\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in e:\python\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in e:\python\lib\site-packages (from spacy) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in e:\python\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in e:\python\lib\site-packages (from spacy) (3.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in e:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\python\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\python\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in e:\python\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in e:\python\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: colorama in e:\python\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in e:\python\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in e:\python\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in e:\python\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in e:\python\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in e:\python\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in e:\python\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.5.0)
# Requirement already satisfied: wrapt in e:\python\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (2.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\python\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\python\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in e:\python\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\python\lib\site-packages (from jinja2->spacy) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# spaCy library installed.
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
print("en_core_web_sm model downloaded.")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# en_core_web_sm model downloaded.

# %% [markdown]
# **Sample text**

# %%
sample_text = """Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976. The company is headquartered in Cupertino, California. In 2023, Apple announced its new Vision Pro headset, attracting significant attention from the tech community. Tim Cook is the current CEO."""
print(sample_text)
# Out:
# Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976. The company is headquartered in Cupertino, California. In 2023, Apple announced its new Vision Pro headset, attracting significant attention from the tech community. Tim Cook is the current CEO.

# %% [markdown]
# **Loading Model**

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print("en_core_web_sm model loaded.")
# Out:
# en_core_web_sm model loaded.

# %%
doc = nlp(sample_text)
print("Extracted Entities:")

for ent in doc.ents:
    print(f"- Text: {ent.text}, Label: {ent.label_}, Explanation: {spacy.explain(ent.label_)}")
# Out:
# Extracted Entities:
# - Text: Apple Inc., Label: ORG, Explanation: Companies, agencies, institutions, etc.
# - Text: Steve Jobs, Label: PERSON, Explanation: People, including fictional
# - Text: Steve Wozniak, Label: PERSON, Explanation: People, including fictional
# - Text: Ronald Wayne, Label: PERSON, Explanation: People, including fictional
# - Text: April 1976, Label: DATE, Explanation: Absolute or relative dates or periods
# - Text: Cupertino, Label: GPE, Explanation: Countries, cities, states
# - Text: California, Label: GPE, Explanation: Countries, cities, states
# - Text: 2023, Label: DATE, Explanation: Absolute or relative dates or periods
# - Text: Apple, Label: ORG, Explanation: Companies, agencies, institutions, etc.
# - Text: Vision Pro, Label: ORG, Explanation: Companies, agencies, institutions, etc.
# - Text: Tim Cook, Label: PERSON, Explanation: People, including fictional

# %%
gold_standard = [
    {'text': 'Apple Inc.', 'label': 'ORG', 'start_char': 0, 'end_char': 10},
    {'text': 'Steve Jobs', 'label': 'PERSON', 'start_char': 26, 'end_char': 36},
    {'text': 'Steve Wozniak', 'label': 'PERSON', 'start_char': 38, 'end_char': 51},
    {'text': 'Ronald Wayne', 'label': 'PERSON', 'start_char': 57, 'end_char': 69},
    {'text': 'April 1976', 'label': 'DATE', 'start_char': 73, 'end_char': 83},
    {'text': 'Cupertino', 'label': 'GPE', 'start_char': 111, 'end_char': 120},
    {'text': 'California', 'label': 'GPE', 'start_char': 122, 'end_char': 132},
    {'text': '2023', 'label': 'DATE', 'start_char': 138, 'end_char': 142},
    {'text': 'Apple', 'label': 'ORG', 'start_char': 144, 'end_char': 149},
    {'text': 'Vision Pro', 'label': 'ORG', 'start_char': 168, 'end_char': 178},
    {'text': 'Tim Cook', 'label': 'PERSON', 'start_char': 226, 'end_char': 234}
]

print("Gold standard dataset created.")
print(gold_standard)
# Out:
# Gold standard dataset created.
# [{'text': 'Apple Inc.', 'label': 'ORG', 'start_char': 0, 'end_char': 10}, {'text': 'Steve Jobs', 'label': 'PERSON', 'start_char': 26, 'end_char': 36}, {'text': 'Steve Wozniak', 'label': 'PERSON', 'start_char': 38, 'end_char': 51}, {'text': 'Ronald Wayne', 'label': 'PERSON', 'start_char': 57, 'end_char': 69}, {'text': 'April 1976', 'label': 'DATE', 'start_char': 73, 'end_char': 83}, {'text': 'Cupertino', 'label': 'GPE', 'start_char': 111, 'end_char': 120}, {'text': 'California', 'label': 'GPE', 'start_char': 122, 'end_char': 132}, {'text': '2023', 'label': 'DATE', 'start_char': 138, 'end_char': 142}, {'text': 'Apple', 'label': 'ORG', 'start_char': 144, 'end_char': 149}, {'text': 'Vision Pro', 'label': 'ORG', 'start_char': 168, 'end_char': 178}, {'text': 'Tim Cook', 'label': 'PERSON', 'start_char': 226, 'end_char': 234}]

# %%
predicted_entities = []
for ent in doc.ents:
    predicted_entities.append({
        'text': ent.text,
        'label': ent.label_,
        'start_char': ent.start_char,
        'end_char': ent.end_char
    })

print("Predicted entities extracted and formatted:")
print(predicted_entities)
# Out:
# Predicted entities extracted and formatted:
# [{'text': 'Apple Inc.', 'label': 'ORG', 'start_char': 0, 'end_char': 10}, {'text': 'Steve Jobs', 'label': 'PERSON', 'start_char': 26, 'end_char': 36}, {'text': 'Steve Wozniak', 'label': 'PERSON', 'start_char': 38, 'end_char': 51}, {'text': 'Ronald Wayne', 'label': 'PERSON', 'start_char': 57, 'end_char': 69}, {'text': 'April 1976', 'label': 'DATE', 'start_char': 73, 'end_char': 83}, {'text': 'Cupertino', 'label': 'GPE', 'start_char': 117, 'end_char': 126}, {'text': 'California', 'label': 'GPE', 'start_char': 128, 'end_char': 138}, {'text': '2023', 'label': 'DATE', 'start_char': 143, 'end_char': 147}, {'text': 'Apple', 'label': 'ORG', 'start_char': 149, 'end_char': 154}, {'text': 'Vision Pro', 'label': 'ORG', 'start_char': 173, 'end_char': 183}, {'text': 'Tim Cook', 'label': 'PERSON', 'start_char': 251, 'end_char': 259}]

# %%
true_positives = 0
false_positives = 0
false_negatives = 0

def match_entity(entity1, entity2):
    return (
        entity1['text'] == entity2['text'] and
        entity1['label'] == entity2['label'] and
        entity1['start_char'] == entity2['start_char'] and
        entity1['end_char'] == entity2['end_char']
    )

matched_predicted_indices = set()
for gold_ent in gold_standard:
    found_match = False
    for i, pred_ent in enumerate(predicted_entities):
        if match_entity(gold_ent, pred_ent):
            true_positives += 1
            found_match = True
            matched_predicted_indices.add(i)
            break
    if not found_match:
        false_negatives += 1


for i, pred_ent in enumerate(predicted_entities):
    if i not in matched_predicted_indices:
        false_positives += 1

print(f"True Positives: {true_positives}")
print(f"False Positives: {false_positives}")
print(f"False Negatives: {false_negatives}")
# Out:
# True Positives: 5
# False Positives: 6
# False Negatives: 6

# %% [markdown]
# **Recall , Precision and f1 score**

# %%
precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1_score:.4f}")
# Out:
# Precision: 0.4545
# Recall: 0.4545
# F1-score: 0.4545
